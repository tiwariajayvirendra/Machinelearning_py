# %%
from sklearn.linear_model import LogisticRegression
import numpy as np
import pandas as pd

# %%
data=pd.read_excel(r"C:/Users/ajayt/OneDrive/Desktop/DataSets/study.xlsx")

# %%
data.head()
# Out:
#    HS  Result
# 0   1       0
# 1   2       0
# 2   3       0
# 3   4       0
# 4   5       1

# %%
X=data.iloc[:,0:1]
X.shape
# Out:
# (12, 1)

# %%
y=data.iloc[:,1]

# %%
y.shape
# Out:
# (12,)

# %%
model=LogisticRegression()

# %%
model.fit(X,y)
# Out:
# LogisticRegression()

# %%
hours=[[3.5]]

# %%
prediction=model.predict(hours)
# Out:
# C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
probability=model.predict_proba(hours)
# Out:
# C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print("Prediction:",prediction[0])
print('Probability:',probability[0][0])
print('Probability of Pass',probability[0][1])
# Out:
# Prediction: 0
# Probability: 0.7639023390397979
# Probability of Pass 0.23609766096020218

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"C:/Users/ajayt/OneDrive/Desktop/DataSets/spam.csv",encoding='latin-1')

# %%
data.head()
# Out:
#    HS  Result
# 0   1       0
# 1   2       0
# 2   3       0
# 3   4       0
# 4   5       1

# %%
data.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 data.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'], axis=1)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6284                 weight  250.0   150.0
#    6285         falcon  speed   320.0   250.0
#    6286                 weight  1.0     0.8
#    6287         """
# -> 6288         return super().drop(
#    6289             labels=labels,
#    6290             axis=axis,
#    6291             index=index,
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
#    4642         for axis, labels in axes.items():
# ...

# %%
data.isna().sum()
# Out:
# HS        0
# Result    0
# dtype: int64

# %%
X=data['message']
y=data['label']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer=TfidfVectorizer(stop_words='english')
X_vec=vectorizer.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X_vec,y,test_size=.2,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 X_train,X_test,y_train,y_test=train_test_split(X_vec,y,test_size=.2,random_state=42)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
# ...

# %%
logistic=LogisticRegression()

# %%
logistic.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 logistic.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %%
pred=logistic.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 pred=logistic.predict(x_test)
#
# NameError: name 'x_test' is not defined

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
accuracy_score(y_test,pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 accuracy_score(y_test,pred)
#
# NameError: name 'y_test' is not defined
