# %%
from sklearn.matrix import confusion_matrix
from sklearn.metrix import accuracy_score
from sklearn.metrix import classification_report
actual = [1,1,0,1,0,0,1,0,0,0]
predicted = [1,0,0,1,0,0,1,1,1,0]
results = confusion_matrix(actual, predicted)
print("Confusion Matrix: ")
print(results)
print("accuracy Score: ",accuracy_score(actual, predicted))
print('')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from sklearn.matrix import confusion_matrix
#       2 from sklearn.metrix import accuracy_score
#       3 from sklearn.metrix import classification_report
#       4 actual = [1,1,0,1,0,0,1,0,0,0]
#
# ModuleNotFoundError: No module named 'sklearn.matrix'

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.0.2)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 results
#
# NameError: name 'results' is not defined

# %%
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

actual = [1,1,0,1,0,0,1,0,0,0]
predicted = [1,0,0,1,0,0,1,1,1,0]

# Confusion Matrix
results = confusion_matrix(actual, predicted)
print("Confusion Matrix: ")
print(results)

# Accuracy Score
print("Accuracy Score:", accuracy_score(actual, predicted))

# Classification Report
print("\nClassification Report:\n", classification_report(actual, predicted))
# Out:
# Confusion Matrix:
# [[4 2]
#  [1 3]]
# Accuracy Score: 0.7
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73         6
#            1       0.60      0.75      0.67         4
#
#     accuracy                           0.70        10
#    macro avg       0.70      0.71      0.70        10
# weighted avg       0.72      0.70      0.70        10

# %%
#
