# %%
#1D CNN  
#Time Series Prediction
# Odio Speech Recogni
# IOT
# Stock Price 
# How CNN 1 D work 

a=[10,12,15,20,22,25,30,28,26,24]

# classify time series . filter size 3


[10,12,15]
[12,15,20]
[15,20,22]
[20,22,25]
[22,25,30]
[25,30,28]
[30,28,26]
[28,26,24]
[26,24,0]
[24,0,0]
[0,0,0]
# Out:
# [0, 0, 0]

# %%
import numpy as np 
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv1D,MaxPooling1D, Flatten, Dense

# %%
# Create sample Data Set 
X=np.random.rand(1000,100,1)
X.shape
# Out:
# (1000, 100, 1)

# %%
y=np.random.randint(0,2,1000)

# %%
y.shape
# Out:
# (1000,)

# %%
# Create Cnn 1d model 

model = Sequential([Conv1D(filters=32,kernel_size=3,
                    activation='relu',input_shape=(100,1)),
                    MaxPooling1D(pool_size=2),Flatten(),
                    Dense(64,activation='relu'),
                    Dense(1,activation='sigmoid')])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_4 (Conv1D)                    │ (None, 98, 32)              │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_2 (MaxPooling1D)       │ (None, 49, 32)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 1568)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │         100,416 │
# ...

# %%
model.fit(X,y,epochs=20,batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8150 - loss: 0.4356 - val_accuracy: 0.4200 - val_loss: 1.0666
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8150 - loss: 0.4177 - val_accuracy: 0.4100 - val_loss: 1.0914
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8175 - loss: 0.4205 - val_accuracy: 0.4150 - val_loss: 1.1418
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8175 - loss: 0.4100 - val_accuracy: 0.4300 - val_loss: 1.1023
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8288 - loss: 0.3963 - val_accuracy: 0.4350 - val_loss: 1.1215
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8288 - loss: 0.3999 - val_accuracy: 0.4250 - val_loss: 1.1322
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8438 - loss: 0.3837 - val_accuracy: 0.4300 - val_loss: 1.1563
# Epoch 8/20
# ...

# %%
#Prediction
sample=np.random.rand(1,100,1)

# %%
prediction=model.predict(sample)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step

# %%
print("Prediction:",prediction)
if prediction [0][0]>=.5:
    print("Class 1")
else:
    print("Class 0")
# Out:
# Prediction: [[0.0834564]]
# Class 0
