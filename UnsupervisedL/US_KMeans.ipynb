# %% [markdown]
# K-MEANS

# %%
from bs4 import  BeautifulSoup
import requests
import os
def main():
    url="https://news.google.com/news/headlines?ned=in&hl=en-IN&gl=IN"
    data = requets.get(url)
    soup = BeautifulSoup(data.content, "")

# %%
import pandas as pd
import numpy as np 
from urlib.request import urlopen
from bs4 import BeautifulSoup

# %%
url=:"http://www.hubertiming.com/results/2017GPTR"
data=urlopen(url)
print(data)

# %%
soup= BeautifulSoup(data,"html.parser") # Three type of parser in data science 1 Lxml ,2.html.praser 3.html5lib
#print(soup)

# %%
title = soup.tilte.get_test()
#print(soup)
print(title)

# %%
# PRint Out the text 
text = soup.get_text(strip=False)
#print(text)
#print(text)

# %%
soup.find_all('a')

# %%
#<a href = "url">Click</a>
all_links = soup.find(

# %%
for link in all_links:
    print(link.get("href"))

# %%
rows = soup.find_all('tr')

# %%
for row in rows:
    row_td= row.find_all('td')
print(row_td)
#Type(row_td)

# %%
str_cells = str (row_td)
cleantext =BeautifulSoup(str_cells, "html.parser").get_text()
print(cleantext)

# %%
import re 
list_rows= []
for row in rows:
    cells = row.find_all("td")
    str_cells=tr(cells)
    clean = re.compile('.</?/w>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)
#print(clean2)
#print(list_rows)
# type(Clan2)

# %%
#Data Manupulaton  and cleaningg labal nmae
