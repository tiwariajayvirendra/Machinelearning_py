# %%
from sklearn.datasets import load_iris

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression

# %%
iris = load_iris()
X=iris.data
y=iris.target

# %%
dmodel=DecisionTreeClassifier(random_state=42)
score=cross_val_score(dmodel,X,y,cv=5)
print("score for each fold",score)
print("Average Accuracy",score.mean())
# Out:
# score for each fold [0.96666667 0.96666667 0.9        0.93333333 1.        ]
# Average Accuracy 0.9533333333333334

# %%
kmodel=KNeighborsClassifier(n_neighbors=5)
score=cross_val_score(kmodel,X,y,cv=5)
print("Score for each fold ",score)
print("Average Accuracy",score.mean())
# Out:
# Score for each fold  [0.96666667 1.         0.93333333 0.96666667 1.        ]
# Average Accuracy 0.9733333333333334

# %%
lmodel=LinearRegression()
score=cross_val_score(lmodel,X,y,cv=5)
print("Score For each fold",score)
print("Average Accuarcay ",score.mean())
# Out:
# Score For each fold [0.         0.85124923 0.         0.76155439 0.        ]
# Average Accuarcay  0.3225607248900084
