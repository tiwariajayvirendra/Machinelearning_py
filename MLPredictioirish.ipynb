# %%
#What is overfitting is 
#Overfiting happens when a model learns the trainng

# %%
# high accuracy 
# poor performance

# How to fix

# use more data 
# apply regularization
# simplyfy model
# cross validation or dropout

# %%
# Underfitting
# When  model is too simple to capture underlaying pattern then underfitting occurs

# Poor Performance 
# Use more complex model 
# add relevant feature 
# train longer 
# reduce regularization


# formula for under fitting
# y= XPower 2+2x+1(Underfiting)

# overfiting
#  y =a base 0 + a base 1 x+a base 2 x** 2+ .....(overfiting)

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(r'C:\Users\ajayt\OneDrive\Desktop\DataSets\iris.csv', names=['sl','sw','pl','pw','classes'])
x_test=data

# %%
data.head()
# Out:
#     sl   sw   pl   pw classes
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa
# 2  4.7  3.2  1.3  0.2  setosa
# 3  4.6  3.1  1.5  0.2  setosa
# 4  5.0  3.6  1.4  0.2  setosa

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2)
#
# NameError: name 'y' is not defined

# %%
data.shape
# Out:
# (150, 5)

# %%
x=data.iloc[:,0:4]

# %%
x.head()
# Out:
#     sl   sw   pl   pw
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
y=data.iloc[:,4:5]

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 y
#       2
#
# NameError: name 'y' is not defined

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y ,test_size=.2,random_state=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,y ,test_size=.2,random_state=10)
#
# NameError: name 'y' is not defined

# %%
y_train.shape
# Out:
# (120, 1)

# %%
x_test.shape
# Out:
# (30, 4)

# %%
y_test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 y_test.shape
#
# NameError: name 'y_test' is not defined

# %%
x_train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 x_train.head()
#
# NameError: name 'x_train' is not defined

# %%
# K nebhougher clasifier
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 knn.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %%
pred = knn.predict(x_test)

# %%
pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pred
#
# NameError: name 'pred' is not defined

# %%
print(accuracy_score(y_test,pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(accuracy_score(y_test,pred))
#
# NameError: name 'y_test' is not defined

# %%
confusion_matrix(y_test,pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 confusion_matrix(y_test,pred)
#
# NameError: name 'y_test' is not defined

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      0.92      0.96        13
#    virginica       0.88      1.00      0.93         7
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.97      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %%
# !pip install flask
# Out:
# ...
#
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
#    ---------------------------------------- 0/2 [werkzeug]
# ...
