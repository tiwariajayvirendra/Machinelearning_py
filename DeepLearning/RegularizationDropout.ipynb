# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
cancer=load_breast_cancer()

# %%
X=cancer.data
y=cancer.target

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,random_state=10)
X_train
# Out:
# array([[2.060e+01, 2.933e+01, 1.401e+02, ..., 2.650e-01, 4.087e-01,
#         1.240e-01],
#        [1.377e+01, 1.327e+01, 8.806e+01, ..., 5.802e-02, 2.823e-01,
#         6.794e-02],
#        [1.537e+01, 2.276e+01, 1.002e+02, ..., 1.476e-01, 2.556e-01,
#         6.828e-02],
#        ...,
#        [1.234e+01, 1.227e+01, 7.894e+01, ..., 1.070e-01, 3.110e-01,
#         7.592e-02],
#        [1.385e+01, 1.721e+01, 8.844e+01, ..., 5.104e-02, 2.364e-01,
#         7.182e-02],
#        [2.073e+01, 3.112e+01, 1.357e+02, ..., 1.659e-01, 2.868e-01,
#         8.218e-02]], shape=(455, 30))

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_train
# Out:
# array([[ 1.77441228,  2.35932161,  1.91226601, ...,  2.25330862,
#          2.03215   ,  2.2008957 ],
#        [-0.1322665 , -1.38923972, -0.19179709, ..., -0.8955658 ,
#         -0.13570987, -0.90420962],
#        [ 0.31439324,  0.82581925,  0.29904315, ...,  0.46725269,
#         -0.59363596, -0.88537737],
#        ...,
#        [-0.53146865, -1.62264951, -0.56053374, ..., -0.15041231,
#          0.35651781, -0.46220569],
#        [-0.10993352, -0.46960512, -0.17643306, ..., -1.0017555 ,
#         -0.92293113, -0.68930044],
#        [ 1.81070339,  2.77712515,  1.73436674, ...,  0.74565834,
#         -0.05853131, -0.11547077]], shape=(455, 30))

# %%
X_train=scaler.fit_transform(X_train)
X_train
# Out:
# array([[ 1.77441228,  2.35932161,  1.91226601, ...,  2.25330862,
#          2.03215   ,  2.2008957 ],
#        [-0.1322665 , -1.38923972, -0.19179709, ..., -0.8955658 ,
#         -0.13570987, -0.90420962],
#        [ 0.31439324,  0.82581925,  0.29904315, ...,  0.46725269,
#         -0.59363596, -0.88537737],
#        ...,
#        [-0.53146865, -1.62264951, -0.56053374, ..., -0.15041231,
#          0.35651781, -0.46220569],
#        [-0.10993352, -0.46960512, -0.17643306, ..., -1.0017555 ,
#         -0.92293113, -0.68930044],
#        [ 1.81070339,  2.77712515,  1.73436674, ...,  0.74565834,
#         -0.05853131, -0.11547077]], shape=(455, 30))

# %%
# Relu is A Activation Function jo zero aur one me batata hai
model=Sequential([Dense(128,activation='relu',kernel_regularizer=l2(0.001),input_shape=(30,)),BatchNormalization(),
                    Dropout(.5),Dense(64,activation='relu',kernel_regularizer=l2(0.001)),Dropout(0.3),Dense(1,activation='sigmoid')])

# Ye wali line thik ho gayi

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
early=EarlyStopping(monitor='val_loss',patience=5,restore_best_weights=True)

# %%
history=model.fit(X_train,y_train,validation_split=.2,epochs=100,batch_size=32,callbacks=[early])
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 92ms/step - accuracy: 0.6291 - loss: 0.8596 - val_accuracy: 0.8791 - val_loss: 0.5417
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8544 - loss: 0.4513 - val_accuracy: 0.8901 - val_loss: 0.4399
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9286 - loss: 0.3206 - val_accuracy: 0.9011 - val_loss: 0.3890
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9451 - loss: 0.2526 - val_accuracy: 0.9121 - val_loss: 0.3591
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9341 - loss: 0.2840 - val_accuracy: 0.9121 - val_loss: 0.3368
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9533 - loss: 0.2563 - val_accuracy: 0.9231 - val_loss: 0.3230
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9423 - loss: 0.2652 - val_accuracy: 0.9231 - val_loss: 0.3113
# Epoch 8/100
# ...

# %%
loss,accuracy=model.evaluate(X_test,y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.3421 - loss: 488.7107

# %%
print("test Accuracy",accuracy)
# Out:
# test Accuracy 0.34210526943206787

# %%
print("Loss ",loss)
# Out:
# Loss  488.7106628417969

# %%
#Deep learning  = CNN, ANN, RNN, C-Vison
