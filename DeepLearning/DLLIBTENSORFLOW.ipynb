# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (2.33.1)
# Requirement already satisfied: setuptools in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (81.0.0)
# Requirement already satisfied: six>=1.12.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (1.81.1)
# Requirement already satisfied: keras>=3.12.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (3.15.0)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (2.4.4)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.4.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [58 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\ajayt\AppData\Local\Temp\pip-build-env-36dlz5u1\overlay\Lib\site-packages\setuptools\_vendor\packaging\requirements.py", line 36, in __init__
#       parsed = _parse_requirement(requirement_string)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\ajayt\AppData\Local\Temp\pip-build-env-36dlz5u1\overlay\Lib\site-packages\setuptools\_vendor\packaging\_parser.py", line 71, in parse_requirement
#       return _parse_requirement(Tokenizer(source, rules=DEFAULT_RULES))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\ajayt\AppData\Local\Temp\pip-build-env-36dlz5u1\overlay\Lib\site-packages\setuptools\_vendor\packaging\_parser.py", line 89, in _parse_requirement
#       url, specifier, marker = _parse_requirement_details(tokenizer)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\ajayt\AppData\Local\Temp\pip-build-env-36dlz5u1\overlay\Lib\site-packages\setuptools\_vendor\packaging\_parser.py", line 135, in _parse_requirement_details
#       marker = _parse_requirement_marker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\ajayt\AppData\Local\Temp\pip-build-env-36dlz5u1\overlay\Lib\site-packages\setuptools\_vendor\packaging\_parser.py", line 156, in _parse_requirement_marker
#       tokenizer.raise_syntax_error(
#     File "C:\Users\ajayt\AppData\Local\Temp\pip-build-env-36dlz5u1\overlay\Lib\site-packages\setuptools\_vendor\packaging\_tokenizer.py", line 166, in raise_syntax_error
#       raise ParserSyntaxError(
#   packaging._tokenizer.ParserSyntaxError: Expected semicolon (after name with no version specifier) or end
#       python_version>"3.7"
#                     ^
#
#   The above exception was the direct cause of the following exception:
#
#   Traceback (most recent call last):
#     File "C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#       main()
#     File "C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#       json_out["return_val"] = hook(**hook_input["kwargs"])
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 143, in get_requires_for_build_wheel
#       return hook(config_settings)
#              ^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\ajayt\AppData\Local\Temp\pip-build-env-36dlz5u1\overlay\Lib\site-packages\setuptools\build_meta.py", line 333, in get_requires_for_build_wheel
#       return self._get_build_requires(config_settings, requirements=[])
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\ajayt\AppData\Local\Temp\pip-build-env-36dlz5u1\overlay\Lib\site-packages\setuptools\build_meta.py", line 301, in _get_build_requires
#       self.run_setup()
#     File "C:\Users\ajayt\AppData\Local\Temp\pip-build-env-36dlz5u1\overlay\Lib\site-packages\setuptools\build_meta.py", line 520, in run_setup
#       super().run_setup(setup_script=setup_script)
#     File "C:\Users\ajayt\AppData\Local\Temp\pip-build-env-36dlz5u1\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#       exec(code, locals())
#     File "<string>", line 40, in <module>
#     File "C:\Users\ajayt\AppData\Local\Temp\pip-build-env-36dlz5u1\overlay\Lib\site-packages\setuptools\__init__.py", line 114, in setup
#       _install_setup_requires(attrs)
#     File "C:\Users\ajayt\AppData\Local\Temp\pip-build-env-36dlz5u1\overlay\Lib\site-packages\setuptools\__init__.py", line 85, in _install_setup_requires
#       dist.parse_config_files(ignore_option_errors=True)
#     File "C:\Users\ajayt\AppData\Local\Temp\pip-build-env-36dlz5u1\overlay\Lib\site-packages\setuptools\dist.py", line 764, in parse_config_files
#       self._finalize_requires()
#     File "C:\Users\ajayt\AppData\Local\Temp\pip-build-env-36dlz5u1\overlay\Lib\site-packages\setuptools\dist.py", line 382, in _finalize_requires
#       self._normalize_requires()
#     File "C:\Users\ajayt\AppData\Local\Temp\pip-build-env-36dlz5u1\overlay\Lib\site-packages\setuptools\dist.py", line 400, in _normalize_requires
#       self.install_requires = list_(map(str, _reqs.parse(install_requires)))
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\ajayt\AppData\Local\Temp\pip-build-env-36dlz5u1\overlay\Lib\site-packages\setuptools\_vendor\packaging\requirements.py", line 38, in __init__
#       raise InvalidRequirement(str(e)) from e
#   packaging.requirements.InvalidRequirement: Expected semicolon (after name with no version specifier) or end
#       python_version>"3.7"
#                     ^
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Failed to build 'tensorflow-gpu' when getting requirements to build wheel

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.21.0'

# %%
tf.config.list_physical_devices("GPU")

# %%
a=tf.constant([1,2,3])
b=tf.constant([[1,2],[3,4]])
print(a)
print(b)

# %%
tf.Variable([10,20,30])

# %%
tf.zeros((2,3))

# %%
tf.ones((3,3))

# %%
tf.random.normal((2,2))

# %%
x=tf.constant([[1,2],[3,4]])

# %%
tf.random.uniform((2,2))

# %%
x=tf.constant([[1,2],[3,4]])
y=tf.constant([[5,6],[7,8]])
print(x+y)

# %%
print(tf.matmul(x,y))

# %%
print(tf.matmul(x,y)) #MatrixMultiplication

# %%
w=tb.Variable(5)
print(w)
w.assign(10)
print(w)

# %%
x=tf.range(12)
print(x)
y=tf.reshape(x,(3,4))
print(y)

# %%
x=tf.Variable(5.0)
print(x)
with tf.GradientTape() as tape:
    y=x*x+3*x
gradiant= tape.gradient(y,x)
print(gradiant)

# %%
y=x^2+3x+2
dy/dx=2x+3
x=5
dy/dx=2(5)+3=13

# %%
# !tensorflow-gpu python_version>"3.7"
# Out:
# 'tensorflow-gpu' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !somepackage python_version>"3.7"
# Out:
# 'somepackage' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install somepackage
# Out:
# Collecting somepackage
#   Downloading somepackage-1.2.3.tar.gz (8.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: somepackage
#   Building wheel for somepackage (pyproject.toml): started
#   Building wheel for somepackage (pyproject.toml): finished with status 'done'
#   Created wheel for somepackage: filename=somepackage-1.2.3-py3-none-any.whl size=9373 sha256=2315901da29eefb7032cf1d79bf2858945f5d06207c2b666604fa74a7e5b18fd
#   Stored in directory: c:\users\ajayt\appdata\local\pip\cache\wheels\ae\86\c4\04a2a7c4d04042fa84d1f9317f12440e8e25d4e98dcf56173b
# Successfully built somepackage
# Installing collected packages: somepackage
# Successfully installed somepackage-1.2.3
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
