# %%
#Dendrites 
#Axon
#Neuron

## Perceptron In deep Learning
#Synapse
#

# %%
#ANN
#Atificial Neural Network

# %%
#Activation Function
# Y= Activation(Sigma(weight notequal input ) +bias)

# %%
#Threshold Function?

# %%
#Sigmoid

# %%
#Rectifier( Relu) Function?

# %%
#Leaky Relu Funtion?

# %%
#Hyperboli  Tangent (TanH) Function

# %%
#Softmax Function (For Multiple Classification) Formula

# %%
#Back Propagation in Deep Learning

# %%
#What is BIAS

# %%
# Gradinent Decent(BGD)
#* Brute Force Algorithm
#*

# %%
# !pip install tensorflow scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df= pd.read_excel(r"C:\Users\ajayt\OneDrive\Desktop\DataSets\DeeplearnigExamp.xlsx")

# %%
X=df.iloc[:,0:2]
y=df.iloc[:,2]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=42)

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

# %%
#Build Deep learing Model
model=Sequential()

# %%
model.add(Dense(8,activation='relu',input_shape=(2,)))
# Out:
# C:\Users\ajayt\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#Hidden Layer 2 
model.add(Dense(4,activation="relu"))

# %%
#Output Layer
model.add(Dense(1,activation="sigmoid"))

# %%
#Compile Model
model.compile(optimizer='adam',loss="binary-crossentropy",metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.fit(X_train,y_train,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# ----------------------------------------------------------------
# ValueError                     Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 model.fit(X_train,y_train,epochs=100,verbose=1)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\losses\__init__.py:207, in get(identifier)
#     205     return obj
#     206 else:
# --> 207     raise ValueError(f"Could not interpret loss identifier: {identifier}")
#
# ...

# %%
#Evaluate
loss,accuracy=model.evaluate(X_test,y_test)
# Out:
# ----------------------------------------------------------------
# ValueError                     Traceback (most recent call last)
# Cell In[32], line 2
#       1 #Evaluate
# ----> 2 loss,accuracy=model.evaluate(X_test,y_test)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\losses\__init__.py:207, in get(identifier)
#     205     return obj
#     206 else:
# --> 207     raise ValueError(f"Could not interpret loss identifier: {identifier}")
#
# ...

# %%
print("Accuracy:" , accuracy)
#type(X_train)
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 print("Accuracy:" , accuracy)
#       2 #type(X_train)
#
# NameError: name 'accuracy' is not defined

# %%
dtest=pd.DataFrame([[7,85]])
prediction=model.predict(dtest)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
