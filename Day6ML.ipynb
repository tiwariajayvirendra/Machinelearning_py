# %%
import speech_recognition as sr 
r=sr.Recognizer()
with sr.Microphone() as source:
    print("Speak Somthing...")
    r.adjust_for_ambient_noise(source)
    try:
        audio=r.listen(source)
        text=r.reconize_google(audio,language='hi-IN')
        print("You Said :" , text)
    except sr.UnknownValueError:
        print("Could not recognise")

# %%
# !pip install SpeechRecognition
# Out:
# ...
#   Using cached speechrecognition-3.16.1-py3-none-any.whl.metadata (28 kB)
# ...
# Using cached speechrecognition-3.16.1-py3-none-any.whl (32.9 MB)
# ...

# %%
# !pip install pyttsx3
# Out:
# ...
#   Using cached pyttsx3-2.99-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached comtypes-1.4.16-py3-none-any.whl.metadata (7.8 kB)
# ...
#   Using cached pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# ...
# Using cached pyttsx3-2.99-py3-none-any.whl (32 kB)
# Using cached comtypes-1.4.16-py3-none-any.whl (296 kB)
# Using cached pypiwin32-223-py3-none-any.whl (1.7 kB)
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.5 MB 6.7 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/9.5 MB 4.8 MB/s eta 0:00:02
#    -------------- ------------------------- 3.4/9.5 MB 5.9 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.5 MB 6.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.5/9.5 MB 5.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.5 MB 5.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.5 MB 6.1 MB/s eta 0:00:01
# ...

# %%
# !pip install pyaudio
# Out:
# ...
# WARNING: Cache entry deserialization failed, entry ignored

# %%
import speech_recognition as sr
import pyttsx3
import os
import datetime

engine=pyttsx3.init()

def speak(text):
    print(text)
    engine.say(text)
    engine.runAndWait()
r=sr.Recognizer()
def take_command():
    with sr.Microphone() as source:
        print("Listening...")
        r.adjust_for_ambient_noise(source)
        audio=r.listen(source)
        try:
            command=r.recognize_google(audio)
            command=command.lower()
            print("you said:",command)
            return command
        except sr.UnknownValueError:
            return ""

while True:
    command=take_command()
    if "notepad" in command:
        speak("Opening Notepad")
        os.system('notepad')
    elif 'chrome' in command:
        speak("opening Chrome")
        os.system("start Crome")
    elif 'exit' in command:
        speak("Goodbye")
        break
    else:
        print("Command Not Recognize")

# %%
# !pip install gtts
# Out:
# ...
#   Using cached gTTS-2.5.4-py3-none-any.whl.metadata (4.1 kB)
# ...
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# ...
# Using cached gTTS-2.5.4-py3-none-any.whl (29 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# ...
#
#   Attempting uninstall: click
#
#     Found existing installation: click 8.3.3
#
#     Uninstalling click-8.3.3:
#
#       Successfully uninstalled click-8.3.3
#
#    ---------------------------------------- 0/2 [click]
#    ---------------------------------------- 0/2 [click]
#    -------------------- ------------------- 1/2 [gtts]
#    -------------------- ------------------- 1/2 [gtts]
#    ---------------------------------------- 2/2 [gtts]
#
# ...

# %%
# !pip install pipwin
# Out:
# ...
#   Using cached pipwin-0.5.2.tar.gz (7.9 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached docopt-0.6.2.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached PyPrind-2.11.3-py2.py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached Js2Py-0.74-py3-none-any.whl.metadata (868 bytes)
# ...
#   Using cached pySmartDL-1.3.4-py3-none-any.whl.metadata (2.8 kB)
# ...

# %%
# !pip install pyaudio

# %%
import speech_recognition as sr
import pyttsx3
import os
import datetime

engine = pyttsx3.init()

def speak(text):
    print(text)
    # engine.sy(text)   // ❌ गलत method
    engine.say(text)    # ✅ सही method
    engine.runAndWait()

r = sr.Recognizer()

def take_command():
    with sr.Microphone() as source:
        print("Listening...")
        r.adjust_for_ambient_noise(source)
        audio = r.listen(source)
        try:
            command = r.recognize_google(audio)
            command = command.lower()
            print("You said:", command)
            return command
        except sr.UnknownValueError:
            return ""

while True:
    command = take_command()
    if "notepad" in command:
        speak("Opening Notepad")
        os.system('notepad')
    # elif 'Chrome' in command:   // ❌ capital लिखा है, लेकिन command.lower() किया है
    elif "chrome" in command:     # ✅ lowercase सही है
        speak("Opening Chrome")
        # os.system("start Crome")   // ❌ spelling mistake
        os.system("start chrome")    # ✅ spelling सही
    elif "exit" in command:
        speak("Goodbye")
        break
    else:
        # print("Command Not Recognize")   // ❌ grammar गलत
        print("Command Not Recognized")    # ✅ grammar सही

# %%
# !pip install pywin32

# %%
import pywintypes
import pythoncom

# %%
import sounddevice as sd
import speech_recognition as sr
import numpy as np
import os

r = sr.Recognizer()

def record_audio(duration=5, fs=16000):
    print("Listening...")
    audio = sd.rec(int(duration * fs), samplerate=fs, channels=1, dtype='int16')
    sd.wait()
    return np.squeeze(audio)

def recognize_speech(audio, fs=16000):
    try:
        audio_data = sr.AudioData(audio.tobytes(), fs, 2)
        text = r.recognize_google(audio_data, language="en-IN")
        print("You said:", text)
        return text.lower()
    except sr.UnknownValueError:
        print("Could not understand audio")
        return ""
    except sr.RequestError:
        print("API unavailable")
        return ""

while True:
    audio = record_audio()
    command = recognize_speech(audio)

    if "notepad" in command:
        print("Opening Notepad...")
        os.system("notepad")
    elif "chrome" in command:
        print("Opening Chrome...")
        os.system("start chrome")
    elif "exit" in command:
        print("Goodbye!")
        break
    else:
        print("Command Not Recognized")

# %%
import speech_recognition as sr
import pyttsx3
import os
import datetime

engine=pyttsx3.init()

def speak(text):
    print(text)
    engine.say(text)
    engine.runAndWait()
r=sr.Recognizer()
def take_command():
    with sr.Microphone() as source:
        print("Listening...")
        r.adjust_for_ambient_noise(source)
        audio=r.listen(source)
        try:
            command=r.recognize_google(audio)
            command=command.lower()
            print("you said:",command)
            return command
        except sr.UnknownValueError:
            return ""

while True:
    command=take_command()
    if "notepad" in command:
        speak("Opening Notepad")
        os.system('notepad')
    elif 'chrome' in command:
        speak("opening Chrome")
        os.system("start Crome")
    elif 'exit' in command:
        speak("Goodbye")
        break
    else:
        print("Command Not Recognize")
